# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
input_file=pd.read_csv('test_dataset.csv')

# %%
half = len(input_file)/2
print(half)
# Out:
# 1937.5

# %%
print(input_file.shape)
pd.set_option('max_columns', 120)
pd.set_option('max_colwidth', 5000)
input_file=input_file.dropna(thresh=half,axis=1)
print(input_file.shape)
# Out:
# (3875, 69)
# (3875, 58)

# %%
input_file.head(10)
# Out:
#             P. Name P. Name Kepler P. Zone Class P. Mass Class  \
# 0       1RXS 1609 b            NaN          Cold        Jovian
# 1    1SWASP J1407 b            NaN          Cold        Jovian
# 2  2M 0103-55(AB) b            NaN          Cold        Jovian
# 3      2M 0122-24 b            NaN          Cold        Jovian
# 4      2M 0219-39 b            NaN          Cold        Jovian
# 5      2M 0441+23 b            NaN          Cold        Jovian
# 6      2M 0746+20 b            NaN          Cold        Jovian
# 7      2M 1207-39 b            NaN          Cold        Jovian
# 8      2M 1938+46 b            NaN          Cold        Jovian
# 9      2M 2140+16 b            NaN          Cold        Jovian
#
#   P. Composition Class P. Atmosphere Class P. Habitable Class  P. Mass (EU)  \
# 0                  gas       hydrogen-rich      non-habitable       4451.16
# 1                  gas       hydrogen-rich      non-habitable       6358.80
# ...

# %%
input_file.shape
# Out:
# (3875, 58)

# %%
input_file=input_file.drop(['P. Name','P. Name Kepler','S. Name','P. Disc. Year'],axis=1)

# %%
input_file.shape
# Out:
# (3875, 54)

# %%
for col in input_file.columns:
        if len(input_file[col].unique())<5:
            print(input_file[col].value_counts())
            print()
# Out:
# Hot     3251
# Cold     345
# Warm     233
# Name: P. Zone Class, dtype: int64
#
# metals-rich      2372
# hydrogen-rich    1041
# no-atmosphere     377
# Name: P. Atmosphere Class, dtype: int64
#
# 0    3875
# Name: P. Int ESI, dtype: int64
#
# 0    3875
# Name: P. Surf ESI, dtype: int64
#
# 0    3618
# 1     257
# Name: S. HabCat, dtype: int64
#
# 0    3820
# 1      55
# Name: P. Habitable, dtype: int64
#
# 0    3835
# 1      40
# Name: P. Hab Moon, dtype: int64
#
# 1    3853
# 0      22
# Name: P. Confirmed, dtype: int64

# %%
input_file=input_file.drop(['P. Int ESI','P. Surf ESI'],axis=1)

# %%
input_file.shape
# Out:
# (3875, 52)

# %%
input_file.head(5)
# Out:
#   P. Zone Class P. Mass Class P. Composition Class P. Atmosphere Class  \
# 0          Cold        Jovian                  gas       hydrogen-rich
# 1          Cold        Jovian                  gas       hydrogen-rich
# 2          Cold        Jovian                  gas       hydrogen-rich
# 3          Cold        Jovian                  gas       hydrogen-rich
# 4          Cold        Jovian                  gas       hydrogen-rich
#
#   P. Habitable Class  P. Mass (EU)  P. Radius (EU)  P. Density (EU)  \
# 0      non-habitable       4451.16           19.04             0.64
# 1      non-habitable       6358.80           10.94             4.86
# 2      non-habitable       4133.22           11.40             2.79
# 3      non-habitable       6358.80           11.20             4.53
# 4      non-habitable       4419.37           16.13             1.05
#
#    P. Gravity (EU)  P. Esc Vel (EU) P. SFlux Min (EU) P. SFlux Mean (EU)  \
# ...

# %%
for col in input_file.columns:
        if len(input_file[col].unique())<10:
            print(input_file[col].value_counts())
            print()
# Out:
# Hot     3251
# Cold     345
# Warm     233
# Name: P. Zone Class, dtype: int64
#
# Jovian         1273
# Superterran     992
# Neptunian       809
# Terran          717
# Subterran        73
# Mercurian         5
# Name: P. Mass Class, dtype: int64
#
# gas            2074
# rocky-iron     1674
# rocky-water      45
# water-gas        24
# iron             17
# Name: P. Composition Class, dtype: int64
#
# metals-rich      2372
# hydrogen-rich    1041
# no-atmosphere     377
# Name: P. Atmosphere Class, dtype: int64
#
# non-habitable        3820
# mesoplanet             31
# psychroplanet          18
# hypopsychroplanet       3
# thermoplanet            3
# Name: P. Habitable Class, dtype: int64
#
# 1    2266
# 2     852
# 3     420
# 4     188
# 5      85
# 6      42
# 7      14
# 8       8
# Name: S. No. Planets, dtype: int64
#
# 0    3500
# 1     326
# 2      36
# 4       7
# 3       6
# Name: S. No. Planets HZ, dtype: int64
#
# 0    3618
# 1     257
# Name: S. HabCat, dtype: int64
# ...

# %%
input_file.shape
# Out:
# (3875, 52)

# %%
print(input_file.isnull().sum())
# Out:
# P. Zone Class                  46
# P. Mass Class                   6
# P. Composition Class           41
# P. Atmosphere Class            85
# P. Habitable Class              0
# P. Mass (EU)                   33
# P. Radius (EU)                 12
# P. Density (EU)                41
# P. Gravity (EU)                41
# P. Esc Vel (EU)                41
# P. SFlux Min (EU)               0
# P. SFlux Mean (EU)              0
# P. SFlux Max (EU)               0
# P. Teq Min (K)                 46
# P. Teq Mean (K)                46
# P. Teq Max (K)                 46
# P. Surf Press (EU)             41
# P. Mag                         56
# P. Appar Size (deg)            12
# P. Period (days)              150
# P. Sem Major Axis (AU)         35
# P. Eccentricity                 0
# P. Mean Distance (AU)          35
# P. Omega (deg)                  0
# S. Constellation                0
# S. Type                        84
# S. Mass (SU)                   47
# ...

# %%
input_file.shape
# Out:
# (3875, 52)

# %%
count=0
for i in input_file.isnull().sum(axis=1):
    if i > 9:
        count+=1
print(count)
# Out:
# 135

# %%
input_file=input_file.dropna(axis=0,thresh=43)

# %%
input_file.shape
# Out:
# (3740, 52)

# %%
count=0
for i in input_file.isnull().sum(axis=1):
    if i > 9:
        count+=1
print(count)
# Out:
# 0

# %%
input_file
# Out:
#      P. Zone Class P. Mass Class P. Composition Class P. Atmosphere Class  \
# 0             Cold        Jovian                  gas       hydrogen-rich
# 1             Cold        Jovian                  gas       hydrogen-rich
# 2             Cold        Jovian                  gas       hydrogen-rich
# 3             Cold        Jovian                  gas       hydrogen-rich
# 4             Cold        Jovian                  gas       hydrogen-rich
# 5             Cold        Jovian                  gas       hydrogen-rich
# 6             Cold        Jovian                  gas       hydrogen-rich
# 7             Cold        Jovian                  gas       hydrogen-rich
# 8             Cold        Jovian                  gas       hydrogen-rich
# 9             Cold        Jovian                  gas       hydrogen-rich
# 10            Cold        Jovian                  gas       hydrogen-rich
# 11            Cold        Jovian                  gas       hydrogen-rich
# ...

# %%
count=0
for i in input_file.isnull().sum(axis=1):
    if i > 0:
        count+=1
print(count)
# Out:
# 2941

# %%
float_list=dict()
for i in input_file.columns:
        #print(input_file[i].dtype)
        if input_file[i].dtype=='float64':
            float_list[i]=input_file[i].mean()
            print(i,':',float_list[i])
print(len(float_list))
# Out:
# P. Mass (EU) : 482.2151096256672
# P. Radius (EU) : 5.23214705882353
# P. Density (EU) : 1.5010508021390025
# P. Gravity (EU) : 5.941949197860967
# P. Esc Vel (EU) : 4.062518716577557
# P. Teq Min (K) : 760.9932352941181
# P. Teq Mean (K) : 772.2216577540119
# P. Teq Max (K) : 794.2739839572206
# P. Surf Press (EU) : 4030.2071390374404
# P. Mag : -23.67813368983957
# P. Appar Size (deg) : 9.998283422459894
# P. Period (days) : 718.368178590932
# P. Sem Major Axis (AU) : 9.048633368983898
# P. Eccentricity : 0.060446524064171184
# P. Mean Distance (AU) : 9.015122994652451
# P. Omega (deg) : 39.371470588235276
# S. Mass (SU) : 0.9783373493975936
# S. Radius (SU) : 1.4933198489751924
# S. Teff (K) : 5466.089986504723
# S. Luminosity (SU) : 4.7477528558823705
# S. [Fe/H] : -0.06071394910461842
# S. Age (Gyrs) : 4.205140795802378
# S. Appar Mag : 12.237222991689753
# S. Distance (pc) : 537.984548250673
# S. RA (hrs) : 16.60986914438497
# S. DEC (deg) : 25.375336898395766
# ...

# %%
input_file=input_file.fillna(float_list)

# %%
mode_list=dict()
for i in input_file.columns:
        #print(input_file[i].dtype)
        if input_file[i].dtype!='float64':
            #mode_list[i]=input_file[i].mode()
            #print(i,':',mode_list[i])
            print(i, ': ',input_file[i].mode())
#print(len(mode_list))
# Out:
# P. Zone Class :  0    Hot
# dtype: object
# P. Mass Class :  0    Jovian
# dtype: object
# P. Composition Class :  0    gas
# dtype: object
# P. Atmosphere Class :  0    metals-rich
# dtype: object
# P. Habitable Class :  0    non-habitable
# dtype: object
# P. SFlux Min (EU) :  0    1.56E-09
# 1       16.15
# 2    4.187054
# 3     59.8363
# 4    8.198086
# 5    809.9706
# dtype: object
# P. SFlux Mean (EU) :  0    1.56E-09
# 1    1.65E-05
# 2       16.15
# 3    4.187055
# 4     59.8363
# 5    8.198087
# 6    809.9708
# dtype: object
# P. SFlux Max (EU) :  0    1.56E-09
# 1       16.15
# 2    4.187056
# 3    59.83632
# 4    8.198089
# 5    809.9709
# dtype: object
# S. Constellation :  0    Cyg
# dtype: object
# S. Type :  0    G
# dtype: object
# S. No. Planets :  0    1
# dtype: int64
# S. No. Planets HZ :  0    0
# dtype: int64
# S. HabCat :  0    0
# dtype: int64
# P. Habitable :  0    0
# dtype: int64
# P. Hab Moon :  0    0
# dtype: int64
# P. Confirmed :  0    1
# ...

# %%
input_file['P. SFlux Min (EU)']=pd.to_numeric(input_file['P. SFlux Min (EU)'])
input_file['P. SFlux Mean (EU)']=pd.to_numeric(input_file['P. SFlux Mean (EU)'])
input_file['P. SFlux Max (EU)']=pd.to_numeric(input_file['P. SFlux Max (EU)'])

# %%
print(input_file['P. SFlux Min (EU)'].dtype)
# Out:
# float64

# %%
float_list=dict()
for i in input_file.columns:
        #print(input_file[i].dtype)
        if input_file[i].dtype=='float64':
            float_list[i]=input_file[i].mean()
            print(i,':',float_list[i])
print(len(float_list))
# Out:
# P. Mass (EU) : 482.2151096256672
# P. Radius (EU) : 5.23214705882353
# P. Density (EU) : 1.5010508021390025
# P. Gravity (EU) : 5.941949197860967
# P. Esc Vel (EU) : 4.062518716577557
# P. SFlux Min (EU) : 828.1651454449743
# P. SFlux Mean (EU) : 841.219760837531
# P. SFlux Max (EU) : 867.8369522523427
# P. Teq Min (K) : 760.9932352941181
# P. Teq Mean (K) : 772.2216577540119
# P. Teq Max (K) : 794.2739839572206
# P. Surf Press (EU) : 4030.2071390374404
# P. Mag : -23.67813368983957
# P. Appar Size (deg) : 9.998283422459894
# P. Period (days) : 718.3681785909334
# P. Sem Major Axis (AU) : 9.048633368983898
# P. Eccentricity : 0.060446524064171184
# P. Mean Distance (AU) : 9.015122994652451
# P. Omega (deg) : 39.371470588235276
# S. Mass (SU) : 0.9783373493975936
# S. Radius (SU) : 1.4933198489751927
# S. Teff (K) : 5466.089986504711
# S. Luminosity (SU) : 4.7477528558823705
# S. [Fe/H] : -0.06071394910461548
# S. Age (Gyrs) : 4.205140795802357
# S. Appar Mag : 12.237222991689872
# ...

# %%
input_file=input_file.fillna(float_list)

# %%
print(input_file.isnull().sum())
# Out:
# P. Zone Class                 0
# P. Mass Class                 1
# P. Composition Class          0
# P. Atmosphere Class           0
# P. Habitable Class            0
# P. Mass (EU)                  0
# P. Radius (EU)                0
# P. Density (EU)               0
# P. Gravity (EU)               0
# P. Esc Vel (EU)               0
# P. SFlux Min (EU)             0
# P. SFlux Mean (EU)            0
# P. SFlux Max (EU)             0
# P. Teq Min (K)                0
# P. Teq Mean (K)               0
# P. Teq Max (K)                0
# P. Surf Press (EU)            0
# P. Mag                        0
# P. Appar Size (deg)           0
# P. Period (days)              0
# P. Sem Major Axis (AU)        0
# P. Eccentricity               0
# P. Mean Distance (AU)         0
# P. Omega (deg)                0
# S. Constellation              0
# S. Type                      24
# S. Mass (SU)                  0
# S. Radius (SU)                0
# S. Teff (K)                   0
# ...

# %%
mode_list=dict()
for i in input_file.columns:
        #print(input_file[i].dtype)
        if input_file[i].dtype!='float64':
            mode_list[i]=input_file[i].mode()[0]
            print(i,':',mode_list[i])
            #print(i, ': ',input_file[i].mode())
#print(type(mode_list['P. Zone Class']))
# Out:
# P. Zone Class : Hot
# P. Mass Class : Jovian
# P. Composition Class : gas
# P. Atmosphere Class : metals-rich
# P. Habitable Class : non-habitable
# S. Constellation : Cyg
# S. Type : G
# S. No. Planets : 1
# S. No. Planets HZ : 0
# S. HabCat : 0
# P. Habitable : 0
# P. Hab Moon : 0
# P. Confirmed : 1
# P. Disc. Method : Primary Transit

# %%
input_file=input_file.fillna(mode_list)

# %%
print(input_file.isnull().sum())
# Out:
# P. Zone Class                0
# P. Mass Class                0
# P. Composition Class         0
# P. Atmosphere Class          0
# P. Habitable Class           0
# P. Mass (EU)                 0
# P. Radius (EU)               0
# P. Density (EU)              0
# P. Gravity (EU)              0
# P. Esc Vel (EU)              0
# P. SFlux Min (EU)            0
# P. SFlux Mean (EU)           0
# P. SFlux Max (EU)            0
# P. Teq Min (K)               0
# P. Teq Mean (K)              0
# P. Teq Max (K)               0
# P. Surf Press (EU)           0
# P. Mag                       0
# P. Appar Size (deg)          0
# P. Period (days)             0
# P. Sem Major Axis (AU)       0
# P. Eccentricity              0
# P. Mean Distance (AU)        0
# P. Omega (deg)               0
# S. Constellation             0
# S. Type                      0
# S. Mass (SU)                 0
# S. Radius (SU)               0
# S. Teff (K)                  0
# S. Luminosity (SU)           0
# ...

# %%
for i in input_file.columns:
        if input_file[i].dtype!='float64' and input_file[i].dtype!='int64':
            print(i,':',input_file[i].value_counts())
            print()
# Out:
# P. Zone Class : Hot     3217
# Cold     297
# Warm     226
# Name: P. Zone Class, dtype: int64
#
# P. Mass Class : Jovian         1165
# Superterran     989
# Neptunian       802
# Terran          707
# Subterran        72
# Mercurian         5
# Name: P. Mass Class, dtype: int64
#
# P. Composition Class : gas            1995
# rocky-iron     1659
# rocky-water      45
# water-gas        24
# iron             17
# Name: P. Composition Class, dtype: int64
#
# P. Atmosphere Class : metals-rich      2369
# hydrogen-rich     994
# no-atmosphere     377
# Name: P. Atmosphere Class, dtype: int64
#
# P. Habitable Class : non-habitable        3685
# mesoplanet             31
# psychroplanet          18
# hypopsychroplanet       3
# thermoplanet            3
# Name: P. Habitable Class, dtype: int64
#
# S. Constellation : Cyg    1340
# Lyr     862
# Dra     151
# Aqr      75
# Vir      72
# Cet      58
# Tau      58
# Leo      57
# Sco      51
# Sgr      51
# Cnc      47
# Cen      46
# ...

# %%
input_file.to_csv('cleaned_dataset.csv',index=False)
