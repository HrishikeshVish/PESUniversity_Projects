# %%
import pandas as pd
import csv
data = list(csv.reader(open('cleaned_dataset.csv')))

# %%
print(len(data))
# Out:
# 3741

# %%
test_dataset=[]
validation_dataset=[]
import random
td_size=int(0.7*3740)
vd_size=3740-td_size
temp_data = list(data)
header=temp_data[0]
del(temp_data[0])
count=0
while count!=td_size:
    index=random.randrange(1,len(temp_data))
    test_dataset.append(temp_data[index])
    del(temp_data[index])
    count+=1
validation_dataset=temp_data
print(len(test_dataset),len(validation_dataset))
# Out:
# 2618 1122

# %%
print(test_dataset[0])
# Out:
# ['Hot', 'Superterran', 'rocky-iron', 'metals-rich', 'non-habitable', '8.48', '1.9', '1.23', '2.34', '2.11', '19.820420000000002', '19.820429999999998', '19.820429999999998', '537.6', '537.6', '537.6', '10.4', '-21.84', '3.62', '20.74', '0.138', '0.0', '0.14', '0.0', 'Lyr', 'K', '0.82', '0.78', '5128.0', '0.37746', '0.071', '4.205140795802378', '12.237222991689753', '537.984548250673', '18.9979', '42.0792', '-30.0', '3.0125', '2', '0', '0.478', '1.15', '-2.01', '-0.14', '0.03', '0.33', '0.32', '0', '0', '0', '1', 'Primary Transit']

# %%
data_by_class={}
for row in test_dataset:
    if row[4] not in data_by_class:
        data_by_class[row[4]]=[]
    data_by_class[row[4]].append(row)
for i in data_by_class.keys():
    print(i,len(data_by_class[i]))
# Out:
# non-habitable 2576
# psychroplanet 13
# mesoplanet 24
# thermoplanet 2
# hypopsychroplanet 3

# %%
for i in test_dataset[0]:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
test_df1=[]
test_df1.extend(test_dataset)

# %%
test_dataframe=pd.DataFrame(test_df1,columns=header)
test_dataframe.to_csv('test_dataset.csv')

# %%
test_df=pd.read_csv('test_dataset.csv')

# %%
import statistics
num_column_stats={}
for i in test_df.columns:
    if test_df[i].dtype == 'float64':
        num_column_stats[i]=(statistics.mean(test_df[i]),statistics.stdev(test_df[i]))

# %%
num_column_stats
# Out:
# {'P. Mass (EU)': (495.3929258976318, 1778.0352551602173),
#  'P. Radius (EU)': (5.210511841100076, 4.705164298847491),
#  'P. Density (EU)': (1.4339877769289535, 12.133331411040926),
#  'P. Gravity (EU)': (5.867310924369748, 23.628669789510905),
#  'P. Esc Vel (EU)': (4.08527883880825, 5.573098625935225),
#  'P. SFlux Min (EU)': (764.6830447554127, 13707.418480893379),
#  'P. SFlux Mean (EU)': (778.7167455623847, 13709.004831303564),
#  'P. SFlux Max (EU)': (807.9069603047861, 13712.594159994711),
#  'P. Teq Min (K)': (756.9620702826585, 490.8235027984524),
#  'P. Teq Mean (K)': (768.0867838044309, 491.8089357452122),
#  'P. Teq Max (K)': (790.1071046600458, 496.1657981502269),
#  'P. Surf Press (EU)': (3793.0066080977845, 34483.076323259746),
#  'P. Mag': (-23.62012605042017, 3.8811605784076124),
#  'P. Appar Size (deg)': (9.956191749427044, 9.039901383108798),
#  'P. Period (days)': (870.3038658195019, 16261.597233978373),
#  'P. Sem Major Axis (AU)': (10.782778304048893, 198.46278662004255),
#  'P. Eccentricity': (0.06027501909854851, 0.1414934832524906),
#  'P. Mean Distance (AU)': (10.752761650114591, 198.46226047362654),
#  'P. Omega (deg)': (39.772307104660044, 91.44953305937038),
#  'S. Mass (SU)': (0.9765781843953354, 0.33215755829581195),
#  'S. Radius (SU)': (1.4619441240750493, 3.0951940706967442),
#  'S. Teff (K)': (5467.844144266466, 1296.8568306511636),
#  'S. Luminosity (SU)': (4.579567069900688, 29.70891412629481),
#  'S. [Fe/H]': (-0.06675495482230256, 1.5151897062547168),
#  'S. Age (Gyrs)': (4.169890565233533, 1.757487452746832),
#  'S. Appar Mag': (12.243090319734039, 2.887274067253173),
#  'S. Distance (pc)': (540.3431798796902, 556.6894728112586),
#  'S. RA (hrs)': (16.62284476699771, 5.583335362758325),
#  'S. DEC (deg)': (25.13024152024446, 32.41718708411897),
#  'S. Mag from Planet': (-30.441864018334606, 3.892250106519935),
#  'S. Size from Planet (deg)': (6.932230888317375, 7.083928152763071),
#  'S. Hab Zone Min (AU)': (0.954014998211283, 1.3524438859305115),
#  'S. Hab Zone Max (AU)': (2.2761078442713116, 3.3442551967900918),
#  'P. HZD': (159.64650496562263, 2790.3276412957366),
#  'P. HZC': (3.610294117647059, 5.0731973321197),
#  'P. HZA': (4.720408708938121, 28.350211586604217),
#  'P. HZI': (0.21877769289533996, 0.10837932898830184),
#  'P. ESI': (0.2673109243697479, 0.13594019244462313)}

# %%
import math
def num_probability(x, mean, stdev):
    exponent = math.exp(-(math.pow(x-mean,2)/(2*math.pow(stdev,2))))
    return (1 / (math.sqrt(2*math.pi) * stdev)) * exponent

# %%
attr_stats_by_class={}
for class_name in test_df['P. Habitable Class'].value_counts().keys():
    attr_stats_by_class[class_name]={}
    frame=test_df.loc[test_df['P. Habitable Class']==class_name]
    for col in frame.columns:
        if frame[col].dtype=='float64':
            attr_stats_by_class[class_name][col]=(frame[col].mean(),frame[col].std())

# %%
attr_stats_by_class
# Out:
# {'non-habitable': {'P. Mass (EU)': (503.3485675465838, 1791.3756283762123),
#   'P. Radius (EU)': (5.268117236024848, 4.721211855642784),
#   'P. Density (EU)': (1.4381599378881922, 12.231783117923719),
#   'P. Gravity (EU)': (5.929328416149065, 23.81526207995934),
#   'P. Esc Vel (EU)': (4.121735248447208, 5.610390054226093),
#   'P. SFlux Min (EU)': (777.1379651998324, 13818.404971583768),
#   'P. SFlux Mean (EU)': (791.3982971005533, 13819.99139521492),
#   'P. SFlux Max (EU)': (821.05845397218, 13823.582589553578),
#   'P. Teq Min (K)': (765.4940993788823, 490.1854546888046),
#   'P. Teq Mean (K)': (776.6759704968927, 491.12464005678044),
#   'P. Teq Max (K)': (798.8444487577635, 495.37412145765984),
#   'P. Surf Press (EU)': (3854.682142857136, 34759.74820372046),
#   'P. Mag': (-23.71210015527953, 3.8429394159451986),
#   'P. Appar Size (deg)': (10.06654114906833, 9.070993135202361),
#   'P. Period (days)': (882.756063942334, 16393.375862592493),
#   'P. Sem Major Axis (AU)': (10.953069914596258, 200.07024739953226),
#   'P. Eccentricity': (0.060046583850931735, 0.1418299192146786),
#   'P. Mean Distance (AU)': (10.922721273291955, 200.06973554396174),
#   'P. Omega (deg)': (39.609433229813675, 91.27258213091051),
#   'S. Mass (SU)': (0.9839835740477432, 0.32733738162770715),
#   'S. Radius (SU)': (1.4777250453526762, 3.1176753347293196),
#   'S. Teff (K)': (5491.458062767706, 1286.4714707920198),
#   'S. Luminosity (SU)': (4.648787817934784, 29.944745824952985),
#   'S. [Fe/H]': (-0.06549369570339646, 1.5272564993454312),
#   'S. Age (Gyrs)': (4.177151214534235, 1.7546753683487895),
#   'S. Appar Mag': (12.245181335059707, 2.8823443922583887),
#   'S. Distance (pc)': (546.146828562416, 558.7494950591772),
#   'S. RA (hrs)': (16.630450427018626, 5.572839205947657),
#   'S. DEC (deg)': (25.33998583074533, 32.299499341926015),
#   'S. Mag from Planet': (-30.506482919254687, 3.889680733410336),
#   'S. Size from Planet (deg)': (7.026477626403298, 7.102272158973001),
#   'S. Hab Zone Min (AU)': (0.9653921837411229, 1.3598030190552033),
#   'S. Hab Zone Max (AU)': (2.303024198875119, 3.363288129659858),
#   'P. HZD': (162.25594720496878, 2812.9161949090494),
#   'P. HZC': (3.6716925465838552, 5.091345126037528),
#   'P. HZA': (4.788020186335403, 28.57532167748983),
#   'P. HZI': (0.2141420807453419, 0.10192421322784599),
#   'P. ESI': (0.25964673913043385, 0.12239166564145124)},
#  'mesoplanet': {'P. Mass (EU)': (8.870833333333334, 7.707761710101717),
#   'P. Radius (EU)': (1.7616666666666667, 0.4526027787832493),
#   'P. Density (EU)': (1.205, 0.2462589658486967),
#   'P. Gravity (EU)': (2.2262500000000003, 1.0076913455151268),
#   'P. Esc Vel (EU)': (1.9720833333333336, 0.695863424672616),
#   'P. SFlux Min (EU)': (1.017005108333333, 0.21978776558517207),
#   'P. SFlux Mean (EU)': (1.139185575, 0.23231454598942067),
#   'P. SFlux Max (EU)': (1.3489257666666667, 0.5367029835957976),
#   'P. Teq Min (K)': (254.74999999999997, 14.023458607075074),
#   'P. Teq Mean (K)': (261.55833333333334, 13.328489156254946),
#   'P. Teq Max (K)': (271.33333333333337, 24.2119386050455),
#   'P. Surf Press (EU)': (12.495833333333332, 13.230546972381974),
#   'P. Mag': (-18.45875, 0.5804669222497412),
#   'P. Appar Size (deg)': (3.3491666666666666, 0.8594432812135938),
#   'P. Period (days)': (93.47166666666668, 95.54354207315143),
#   'P. Sem Major Axis (AU)': (0.3125583333333334, 0.2623838739687342),
#   'P. Eccentricity': (0.06000000000000002, 0.09334368472618201),
#   'P. Mean Distance (AU)': (0.3112499999999999, 0.2633118914403849),
#   'P. Omega (deg)': (40.37083333333333, 96.213736157382),
#   'S. Mass (SU)': (0.55125, 0.2551779004333353),
#   'S. Radius (SU)': (0.5316666666666668, 0.24795979103680196),
#   'S. Teff (K)': (4096.416666666667, 864.7256371452345),
#   'S. Luminosity (SU)': (0.18177850000000004, 0.28994128311075856),
#   'S. [Fe/H]': (-0.1135237393967955, 0.19884105213442022),
#   'S. Age (Gyrs)': (4.070261131759225, 1.9663922568086993),
#   'S. Appar Mag': (11.900486207294554, 3.2435967178482845),
#   'S. Distance (pc)': (214.21583333333334, 227.64804532085444),
#   'S. RA (hrs)': (16.56910416666667, 5.774777891492351),
#   'S. DEC (deg)': (18.052183333333335, 34.39000478981049),
#   'S. Mag from Planet': (-26.850000000000005, 0.24847360108225267),
#   'S. Size from Planet (deg)': (1.2841208333333332, 0.5723591248577864),
#   'S. Hab Zone Min (AU)': (0.258375, 0.20950517530185472),
#   'S. Hab Zone Max (AU)': (0.6338333333333334, 0.4911193662278631),
#   'P. HZD': (-0.7466666666666666, 0.16620225150640136),
#   'P. HZC': (-0.1475, 0.03492227394359228),
#   'P. HZA': (0.6320833333333332, 0.84826666831823),
#   'P. HZI': (0.4675, 0.0864895067774623),
#   'P. ESI': (0.78875, 0.06522952785623874)},
#  'psychroplanet': {'P. Mass (EU)': (5.47, 3.874209596808102),
#   'P. Radius (EU)': (1.580769230769231, 0.33532227131675235),
#   'P. Density (EU)': (1.1615384615384614, 0.38641183025899),
#   'P. Gravity (EU)': (1.880769230769231, 0.7719829611511464),
#   'P. Esc Vel (EU)': (1.7076923076923078, 0.5068555653266166),
#   'P. SFlux Min (EU)': (0.41135294615384616, 0.12224754158138598),
#   'P. SFlux Mean (EU)': (0.47829917692307694, 0.13132562019082666),
#   'P. SFlux Max (EU)': (0.5938356153846155, 0.2624644740349185),
#   'P. Teq Min (K)': (202.4538461538462, 15.297854718043281),
#   'P. Teq Mean (K)': (209.82307692307694, 14.172223646165168),
#   'P. Teq Max (K)': (220.45384615384617, 22.222759181546873),
#   'P. Surf Press (EU)': (7.107692307692307, 6.021691558920071),
#   'P. Mag': (-17.293076923076924, 0.5883505844786854),
#   'P. Appar Size (deg)': (3.0030769230769225, 0.6378921619336692),
#   'P. Period (days)': (89.77076923076923, 87.72261067911154),
#   'P. Sem Major Axis (AU)': (0.28746153846153844, 0.2282550785797238),
#   'P. Eccentricity': (0.08153846153846155, 0.10407098169407852),
#   'P. Mean Distance (AU)': (0.2846153846153846, 0.22607577581478386),
#   'P. Omega (deg)': (84.69999999999999, 125.35123985558872),
#   'S. Mass (SU)': (0.42076923076923073, 0.20605264450545716),
#   'S. Radius (SU)': (0.4015384615384615, 0.16727453252294336),
#   'S. Teff (K)': (3713.769230769231, 756.9340739507585),
#   'S. Luminosity (SU)': (0.061059307692307704, 0.08593684109214998),
#   'S. [Fe/H]': (-0.2121647574856812, 0.21683597001366067),
#   'S. Age (Gyrs)': (3.4954279371699633, 1.7336623666571311),
#   'S. Appar Mag': (12.362436075005323, 2.871717625297188),
#   'S. Distance (pc)': (117.76538461538462, 146.09829217661334),
#   'S. RA (hrs)': (14.403246153846153, 7.565685001771198),
#   'S. DEC (deg)': (-2.8467692307692336, 43.50957275526434),
#   'S. Mag from Planet': (-25.907692307692308, 0.31480559731771635),
#   'S. Size from Planet (deg)': (0.9725846153846155, 0.3384305488726696),
#   'S. Hab Zone Min (AU)': (0.157, 0.12206896957594643),
#   'S. Hab Zone Max (AU)': (0.3936153846153847, 0.29082427066917305),
#   'P. HZD': (0.07153846153846155, 0.3051460348162869),
#   'P. HZC': (-0.16846153846153847, 0.22777350423341436),
#   'P. HZA': (0.5453846153846155, 0.6784862487505474),
#   'P. HZI': (0.5753846153846154, 0.13592984615941814),
#   'P. ESI': (0.6884615384615385, 0.07690320256076832)},
#  'hypopsychroplanet': {'P. Mass (EU)': (3.4133333333333336, 3.479142614687321),
#   'P. Radius (EU)': (1.38, 0.3988734135035827),
#   'P. Density (EU)': (1.0166666666666666, 0.15044378795195673),
#   'P. Gravity (EU)': (1.4433333333333334, 0.6553116307020145),
#   'P. Esc Vel (EU)': (1.4066666666666665, 0.5227172594561358),
#   'P. SFlux Min (EU)': (0.2544068, 0.018548429303043443),
#   'P. SFlux Mean (EU)': (0.2650784, 0.02637725838918822),
#   'P. SFlux Max (EU)': (0.27670673333333334, 0.03730376358523804),
#   'P. Teq Min (K)': (180.9, 3.3045423283716584),
#   'P. Teq Mean (K)': (182.66666666666666, 4.461315202194676),
#   'P. Teq Max (K)': (184.5666666666667, 6.091250555783542),
#   'P. Surf Press (EU)': (3.8333333333333335, 4.387862045841155),
#   'P. Mag': (-16.363333333333333, 0.5389186704256338),
#   'P. Appar Size (deg)': (2.62, 0.7631513611335564),
#   'P. Period (days)': (96.64999999999999, 73.54160115200105),
#   'P. Sem Major Axis (AU)': (0.2987, 0.21972020844701567),
#   'P. Eccentricity': (0.02, 0.02),
#   'P. Mean Distance (AU)': (0.3, 0.21656407827707713),
#   'P. Omega (deg)': (0.0, 0.0),
#   'S. Mass (SU)': (0.3833333333333333, 0.2627419519858474),
#   'S. Radius (SU)': (0.3866666666666667, 0.23437861108329264),
#   'S. Teff (K)': (3372.6666666666665, 713.0402045700743),
#   'S. Luminosity (SU)': (0.03283966666666666, 0.028626371064690216),
#   'S. [Fe/H]': (-0.09666666666666668, 0.15176736583776282),
#   'S. Age (Gyrs)': (2.6999999999999997, 1.9157244060668017),
#   'S. Appar Mag': (12.366666666666667, 5.573448962117921),
#   'S. Distance (pc)': (141.36666666666667, 116.99745011466419),
#   'S. RA (hrs)': (20.897599999999997, 1.9179732297401868),
#   'S. DEC (deg)': (26.062566666666665, 27.038311023496515),
#   'S. Mag from Planet': (-25.266666666666666, 0.11547005383792475),
#   'S. Size from Planet (deg)': (0.8912666666666668, 0.42729222241147025),
#   'S. Hab Zone Min (AU)': (0.12633333333333333, 0.09360199428074881),
#   'S. Hab Zone Max (AU)': (0.324, 0.2382582632355067),
#   'P. HZD': (0.7200000000000001, 0.16522711641858306),
#   'P. HZC': (-0.17333333333333334, 0.03511884584284245),
#   'P. HZA': (0.2866666666666666, 0.7650054466037044),
#   'P. HZI': (0.5299999999999999, 0.11269427669584642),
#   'P. ESI': (0.57, 0.045825756949558386)},
#  'thermoplanet': {'P. Mass (EU)': (9.26, 10.620743853421944),
#   'P. Radius (EU)': (1.74, 0.7212489168102785),
#   'P. Density (EU)': (1.205, 0.3747665940288702),
#   'P. Gravity (EU)': (2.23, 1.5273506473629428),
#   'P. Esc Vel (EU)': (1.96, 1.0889444430272832),
#   'P. SFlux Min (EU)': (1.1469418, 0.32264179338963506),
#   'P. SFlux Mean (EU)': (2.0364865, 0.9353643856874709),
#   'P. SFlux Max (EU)': (6.460222, 7.191471126138796),
#   'P. Teq Min (K)': (262.65, 18.73832970144349),
#   'P. Teq Mean (K)': (290.4, 20.506096654409877),
#   'P. Teq Max (K)': (372.75, 136.9665835158343),
#   'P. Surf Press (EU)': (13.15, 16.334166645409248),
#   'P. Mag': (-19.105, 0.26162950903902077),
#   'P. Appar Size (deg)': (3.31, 1.3717871555019026),
#   'P. Period (days)': (387.805, 522.3468503303145),
#   'P. Sem Major Axis (AU)': (1.0355, 1.3357247096613882),
#   'P. Eccentricity': (0.28, 0.39597979746446665),
#   'P. Mean Distance (AU)': (0.865, 1.0960155108391487),
#   'P. Omega (deg)': (10.0, 14.142135623730951),
#   'S. Mass (SU)': (1.045, 1.053589103967956),
#   'S. Radius (SU)': (0.805, 0.7000357133746821),
#   'S. Teff (K)': (6054.5, 3768.172036943112),
#   'S. Luminosity (SU)': (4.387097999999999, 6.188189841225138),
#   'S. [Fe/H]': (-0.14, 0.15556349186104046),
#   'S. Age (Gyrs)': (2.602570397901189, 2.2663767913695088),
#   'S. Appar Mag': (12.7, 4.101219330881975),
#   'S. Distance (pc)': (323.9922741253365, 302.630776311112),
#   'S. RA (hrs)': (15.486899999999999, 5.283360447669645),
#   'S. DEC (deg)': (20.36835, 28.797701481281457),
#   'S. Mag from Planet': (-27.55, 0.6363961030678917),
#   'S. Size from Planet (deg)': (1.1189, 0.985141167549098),
#   'S. Hab Zone Min (AU)': (1.07, 1.3901719318127523),
#   'S. Hab Zone Max (AU)': (2.4795, 3.1841018356830233),
#   'P. HZD': (-0.97, 0.028284271247461926),
#   'P. HZC': (-0.14, 0.02828427124746191),
#   'P. HZA': (0.485, 1.3647160876900366),
#   'P. HZI': (0.42, 0.07071067811865474),
#   'P. ESI': (0.69, 0.02828427124746185)}}

# %%
class_prob={}
for class_name,count in test_df['P. Habitable Class'].value_counts().items():
    class_prob[class_name]=count/len(test_df)
class_prob
# Out:
# {'non-habitable': 0.983957219251337,
#  'mesoplanet': 0.009167303284950344,
#  'psychroplanet': 0.004965622612681436,
#  'hypopsychroplanet': 0.001145912910618793,
#  'thermoplanet': 0.0007639419404125286}

# %%
class_names=['non-habitable','mesoplanet','psychroplanet','hypopsychroplanet','thermoplanet']
def disc_probability(x,attribute,df,class_name):
    frame=df.loc[df['P. Habitable Class']==class_name]
    v_counts=frame[attribute].value_counts()
    #print(v_counts)
    if x in v_counts.keys():
        x_count=v_counts[x]
    else:
        x_count=0
    return x_count/len(frame)

# %%
def predict_class(instance,test_df,class_names,attr_stats_by_class,class_prob):
    class_wise_output={}
    for class_name in class_names:
        class_wise_output[class_name]=class_prob[class_name]
        for i in range(1,len(instance)):
            #print(instance[i],test_df.columns[i],type(instance[i]))
            if i!=5:
                if type(instance[i])==float:
                    mean,std_dev=attr_stats_by_class[class_name][test_df.columns[i]]
                    if std_dev!=0.0:
                        class_wise_output[class_name]*=num_probability(instance[i],mean,std_dev)
                        
                else:
                    class_wise_output[class_name]*=disc_probability(instance[i],test_df.columns[i],test_df,class_name)
    #print(class_wise_output)
    max_class=''
    max_probability=0.0
    for i,j in class_wise_output.items():
        if j > max_probability:
            max_probability=j
            max_class=i
    if max_probability==0.0:
        max_class = 'non-habitable'
    return max_class,max_probability

# %%
validation_dataframe=pd.DataFrame(validation_dataset,columns=header)
validation_dataframe.to_csv('validation_dataset.csv')

# %%
validation_df = pd.read_csv('validation_dataset.csv')

# %%
true_count=0
for row in list(validation_df.itertuples(index=False)):
    predicted_class, prob = predict_class(row,test_df,class_names,attr_stats_by_class,class_prob)
    print(predicted_class,'->',row[5])
    if predicted_class==row[5]:
        true_count+=1
print((true_count/len(validation_df))*100)
# Out:
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> mesoplanet
# non-habitable -> mesoplanet
# non-habitable -> mesoplanet
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> psychroplanet
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> psychroplanet
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# psychroplanet -> psychroplanet
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> mesoplanet
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# mesoplanet -> mesoplanet
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# mesoplanet -> mesoplanet
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> thermoplanet
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> mesoplanet
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> psychroplanet
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# psychroplanet -> psychroplanet
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# non-habitable -> non-habitable
# 99.19786096256684
